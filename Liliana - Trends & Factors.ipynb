# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
annualfoodcpi = Path("Outside Resources/annualfoodcpi.csv")
snap = Path("Outside Resources/US SNAP Participants – US Census.csv")
unemployed = Path("Outside Resources/US Unemployment Percentages (BLS).csv")

# %%
annualfoodcpi_df = pd.read_csv(annualfoodcpi)
snap_df = pd.read_csv(snap)
unemployed_df = pd.read_csv(unemployed)

# %%
trends1_df = pd.merge(annualfoodcpi_df, unemployed_df, how="left", on="Year")
trends1_df.head()
trends1_df.dropna(axis=1)
# Out:
#    Year  Meats, Poultry, Fish, and Eggs  Fruits and Vegetables  \
# 0  2019                         249.785                300.873
# 1  2020                         265.173                304.944
# 2  2021                         282.784                314.813
# 3  2022                         313.667                341.668
# 4  2023                         319.297                350.180
# 5  2024                         326.254                352.801
#
#    Dairy and Related Product  Unemployment %
# 0                    218.677             3.7
# 1                    228.322             8.1
# 2                    231.422             5.3
# 3                    259.184             3.6
# 4                    269.528             3.6
# 5                    268.876             4.0

# %%
fig, ax1 = plt.subplots(figsize=(20, 8))

ax1.plot(trends1_df["Year"], trends1_df["Meats, Poultry, Fish, and Eggs"], label="Meats, Poultry, Fish, and Eggs", color="blue")
ax1.plot(trends1_df["Year"], trends1_df["Fruits and Vegetables"], label="Fruits and Vegetables", color="green")
ax1.plot(trends1_df["Year"], trends1_df["Dairy and Related Product"], label="Dairy and Related Product", color="red")
ax1.set_ylabel("CPI (Consumer Price Index)", color="black")

ax2 = ax1.twinx()  
ax2.plot(trends1_df["Year"], trends1_df["Unemployment %"], label="Unemployment Rate %", color="black", linestyle="dashed")
ax2.set_ylabel("Unemployment %", color="black")

ax1.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.show()

# %%
trends2_df = pd.merge(annualfoodcpi_df, snap_df, how="left", on="Year")
filtered_trends2 = trends2_df[trends2_df["Year"] <= 2023]
filtered_trends2.head(11)
# Out:
#    Year  Meats, Poultry, Fish, and Eggs  Fruits and Vegetables  \
# 0  2019                         249.785                300.873
# 1  2020                         265.173                304.944
# 2  2021                         282.784                314.813
# 3  2022                         313.667                341.668
# 4  2023                         319.297                350.180
#
#    Dairy and Related Product  SNAP Participants %
# 0                    218.677                 10.7
# 1                    228.322                 11.4
# 2                    231.422                 12.4
# 3                    259.184                 12.4
# 4                    269.528                 12.2

# %%
fig, ax1 = plt.subplots(figsize=(20, 8))

ax1.plot(filtered_trends2["Year"], filtered_trends2["Meats, Poultry, Fish, and Eggs"], label="Meats, Poultry, Fish, and Eggs", color="blue")
ax1.plot(filtered_trends2["Year"], filtered_trends2["Fruits and Vegetables"], label="Fruits and Vegetables", color="green")
ax1.plot(filtered_trends2["Year"], filtered_trends2["Dairy and Related Product"], label="Dairy and Related Product", color="red")
ax1.set_ylabel("CPI (Consumer Price Index) %", color="black")

ax2 = ax1.twinx()  
ax2.plot(filtered_trends2["Year"], filtered_trends2["SNAP Participants %"], label="SNAP Participants %", color="black", linestyle="dashed")
ax2.set_ylabel("SNAP Participants %", color="black")

ax1.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.show()

# %%
trends1_filtered = trends1_df[trends1_df["Year"] >= 2020]

fig, ax1 = plt.subplots(figsize=(15, 8))

bar_width = 0.10
years = trends1_filtered["Year"]

x_indexes = np.arange(len(years))

ax1.bar(x_indexes - bar_width, trends1_filtered["Meats, Poultry, Fish, and Eggs"], width=bar_width, label="Meats, Poultry, Fish, and Eggs", color="skyblue")
ax1.bar(x_indexes, trends1_filtered["Fruits and Vegetables"], width=bar_width, label="Fruits and Vegetables", color="lightgreen")
ax1.bar(x_indexes + bar_width, trends1_filtered["Dairy and Related Product"], width=bar_width, label="Dairy and Related Product", color="lightpink")

ax1.set_ylabel("CPI (Consumer Price Index) %", color="black")
ax1.set_xticks(x_indexes)
ax1.set_xticklabels(years)

ax2 = ax1.twinx()
ax2.plot(x_indexes, trends1_filtered["Unemployment %"], label="Unemployment %", color="black", marker="o", linestyle="dashed")
ax2.set_ylabel("Unemployment %", color="black")

ax1.legend(loc="lower left")
ax2.legend(loc="lower right")

plt.title("Food CPI vs. Unemployment % Over Time (2020 to 2024)")

plt.show()

# %%
trends2_filtered = trends2_df[trends2_df["Year"] <= 2023]

fig, ax1 = plt.subplots(figsize=(15, 8))

bar_width = 0.10
years = trends2_filtered["Year"]

x_indexes = np.arange(len(years))

ax1.bar(x_indexes - bar_width, trends2_filtered["Meats, Poultry, Fish, and Eggs"], width=bar_width, label="Meats, Poultry, Fish, and Eggs", color="skyblue")
ax1.bar(x_indexes, trends2_filtered["Fruits and Vegetables"], width=bar_width, label="Fruits and Vegetables", color="lightgreen")
ax1.bar(x_indexes + bar_width, trends2_filtered["Dairy and Related Product"], width=bar_width, label="Dairy and Related Product", color="lightpink")

ax1.set_ylabel("CPI (Consumer Price Index) %", color="black")
ax1.set_xticks(x_indexes)
ax1.set_xticklabels(years)

ax2 = ax1.twinx()
ax2.plot(x_indexes, trends2_filtered["SNAP Participants %"], label="SNAP Participants %", color="black", marker="o", linestyle="dashed")
ax2.set_ylabel("SNAP Participants %", color="black")

ax1.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.title("Food CPI vs. SNAP Participants % Over Time (2019 to 2023)")

plt.show()
